# %% [markdown]
# <a href="https://colab.research.google.com/github/ThamerMalkix0/Capstone-project/blob/main/Model_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
import cv2
import tensorflow as tf
import os

# %%
#create a path variable called HOME
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
#installing YOLOv8 via pip method
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

# checking the version of ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.0/201.2 GB disk)

# %%
# importing YOLO and much more methods with it
from ultralytics import YOLO

from IPython.display import display, Image

# %%
#Inference with Pre-trained COCO Model
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 166.8ms
# Speed: 6.3ms preprocess, 166.8ms inference, 630.7ms postprocess per image at shape (1, 3, 640, 384)

# %%
# Exporting our custom Data-set from robflow
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ntXoACTX3Fy1BN6xl7Z6")
project = rf.workspace("cp2-sgbvv").project("offline-exam-monitoring-4")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to offline-exam-monitoring-4-2 in yolov8:: 100%|██████████| 9844/9844 [00:01<00:00, 5825.97it/s]

# %%
# %cd /content/datasets/offline-exam-monitoring-4-2/
# %ls
# Out:
# /content/datasets/offline-exam-monitoring-4-2
# data.yaml  README.dataset.txt  README.roboflow.txt  test/  train/  valid/

# %%
# Training the model with our custom data-set
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/offline-exam-monitoring-4-2/data.yaml epochs=250 imgsz=800 plots=True
# Out:
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 282MB/s]
# New https://pypi.org/project/ultralytics/8.2.4 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# View the status of your deployment at: https://app.roboflow.com/cp2-sgbvv/offline-exam-monitoring-4/2
# Share your model with the world at: https://universe.roboflow.com/cp2-sgbvv/offline-exam-monitoring-4/model/2
